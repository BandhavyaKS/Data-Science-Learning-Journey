# %% [markdown]
# ## BASIC UNDERSTANDING ON LINEAR REGRESSION ON ADVERTISING DATASET

# %%
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.linear_model import LinearRegression
df=pd.read_csv('Advertising.csv' )
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
plt.scatter(df[['TV']],df['Sales'] ,label='TV')
plt.scatter(df[['Radio']],df['Sales'] ,label='Radio')
plt.legend()
plt.show()# feature name# target name

# %%
X=df[['TV','Radio']]
Y=df['Sales']

# %%
model=LinearRegression()
model.fit(X,Y)
model
# Out:
# LinearRegression()

# %%
model.predict(X)
# Out:
# array([20.55546463, 12.34536229, 12.33701773, 17.61711596, 13.22390813,
#        12.51208449, 11.71821241, 12.10551553,  3.7093792 , 12.55169696,
#         7.0358597 , 17.25652015, 10.60866187,  8.81095051, 18.44466773,
#        20.82891539, 12.90386507, 23.24107626,  9.94121476, 14.15384619,
#        18.12139161, 14.74206357,  6.51417168, 16.54402663,  8.14035215,
#        15.6080206 , 14.96769383, 17.0463346 , 19.39954145,  9.15929748,
#        21.64292187, 11.35791808,  7.65045928, 18.83346334,  7.56302763,
#        16.99280099, 23.36720719, 15.6258994 ,  9.91257829, 20.4405801 ,
#        16.37872122, 17.29870935, 21.5621537 , 13.96692266,  8.9009974 ,
#        15.16263814,  8.88644967, 21.69944046, 16.28690268,  8.18162949,
#        12.64569407,  9.31962792, 20.66180115, 19.96126242, 20.35512357,
#        21.30864743,  8.53774783, 12.76239488, 21.89072858, 18.10746914,
#         5.74497097, 22.90418658, 16.78413768, 13.18474853, 16.96570907,
# ...

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.04575482 0.18799423]
# 2.9210999124051362

# %%
model.predict([[5,0]]) ## 1 row , 2 cloumn
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.14987399])

# %%
model.predict([[5,0],[6,1]])
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.14987399, 3.38362303])

# %%
print(len([[2]]))
## print(len(input))
# Out:
# 1

# %%
print(len([2]))
#print(len(input(value)))
# Out:
# 1

# %%
from  sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pandas as pd
df=pd.read_csv('Advertising.csv' )

##Xtrain,Xtest,Ytrain Ytest=train_test_split(X,Y())

# %%
X=df[['TV','Radio']]
Y=df['Sales']

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,train_size=0.8,random_state=42)

# %%
train_test_split(X,Y,train_size=0.8,random_state=42)
# Out:
# [        TV  Radio
#  79   116.0    7.7
#  197  177.0    9.3
#  38    43.1   26.7
#  24    62.3   12.6
#  122  224.0    2.4
#  ..     ...    ...
#  106   25.0   11.0
#  14   204.1   32.9
#  92   217.7   33.5
#  179  165.6   10.0
#  102  280.2   10.1
#
#  [160 rows x 2 columns],
#          TV  Radio
#  95   163.3   31.6
#  15   195.4   47.7
#  30   292.9   28.3
#  158   11.7   36.9
#  128  220.3   49.0
#  115   75.1   35.0
#  69   216.8   43.9
#  170   50.0   11.6
#  174  222.4    3.4
#  45   175.1   22.5
#  66    31.5   24.6
#  182   56.2    5.7
#  165  234.5    3.4
#  78     5.4   29.9
#  186  139.5    2.1
#  177  170.2    7.8
#  56     7.3   28.1
#  152  197.6   23.3
#  82    75.3   20.3
#  68   237.4   27.5
#  124  229.5   32.3
#  16    67.8   36.6
#  148   38.0   40.3
#  93   250.9   36.5
#  65    69.0    9.3
#  60    53.5    2.0
#  84   213.5   43.0
#  67   139.3   14.5
#  125   87.2   11.8
#  132    8.4   27.2
#  9    199.8    2.6
#  18    69.2   20.5
#  55   198.9   49.4
# ...

# %%
Xtrain
# Out:
#         TV  Radio
# 79   116.0    7.7
# 197  177.0    9.3
# 38    43.1   26.7
# 24    62.3   12.6
# 122  224.0    2.4
# ..     ...    ...
# 106   25.0   11.0
# 14   204.1   32.9
# 92   217.7   33.5
# 179  165.6   10.0
# 102  280.2   10.1
#
# [160 rows x 2 columns]

# %%
model=LinearRegression()

# %%
model.fit(Xtrain,Ytrain)
# Out:
# LinearRegression()

# %%
model=LinearRegression()
model.fit(Xtrain,Ytrain) # Learns the apteern (mx+c) from Xtrain and Ytrain
model
# Out:
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.0447283  0.19066726]
# 3.0282552507833014

# %%
Ypred_train=model.predict(Xtrain)
plt.scatter(Xtrain,Ytrain)
plt.scatter(Xtrain,Ypred_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 Ypred_train=model.predict(Xtrain)
# ----> 2 plt.scatter(Xtrain,Ytrain)
#       3 plt.scatter(Xtrain,Ypred_train)
#
# File c:\Users\ASUS\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3903, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3884 @_copy_docstring_and_deprecators(Axes.scatter)
#    3885 def scatter(
#    3886     x: float | ArrayLike,
#    (...)
#    3901     **kwargs,
#    3902 ) -> PathCollection:
# -> 3903     __ret = gca().scatter(
#    3904         x,
#    3905         y,
#    3906         s=s,
#    3907         c=c,
#    3908         marker=marker,
#    3909         cmap=cmap,
#    3910         norm=norm,
#    3911         vmin=vmin,
#    3912         vmax=vmax,
#    3913         alpha=alpha,
# ...

# %%
print(Ypred_train)
# Out:
# [ 9.68487622 12.71837026 10.04686103  8.217236   13.50499633  5.44234526
#   9.2367496  14.17368175  8.79363904 11.68437447 15.44923645 11.91423888
#  12.74102071 10.7940926   6.59803133  9.90290093  9.55265611 24.05126962
#   7.73734199 12.53390315 17.7655845  15.30253084 11.39569095 10.78520982
#  16.81250842  6.94666054 21.44196794  6.1717484   9.9695358  11.6093231
#   9.34938251  6.61546507 14.90614483 17.31345133 15.68622487 16.33105299
#  15.00648045 19.6688112  13.79569885 21.08444189 12.54920949 13.85203268
#   8.92798986 17.04798425  8.46444851 15.17804086 13.6873588  23.31746523
#  12.63144775 22.85725275  6.65027834 18.44174851 23.20694566 18.72143754
#  17.20743603 16.51183667 12.42725029 11.85401889 16.95166387 14.45824701
#  13.1743387   7.6618471  19.22099902  9.66590382 19.58081299 10.15299342
#   7.09066615 16.68708051 13.82329378 15.15939158 10.997981   20.52746013
#  23.7212268  18.25970378 17.76807847 15.13139658 17.05269456  9.05108433
# ...

# %%
Error=Ytrain-Ypred_train
print(Error)
# Out:
# 79     1.315124
# 197    0.081630
# 38     0.053139
# 24     1.482764
# 122   -1.904996
#          ...
# 106    0.956197
# 14     0.569745
# 92     0.247040
# 179    0.258065
# 102   -2.686865
# Name: Sales, Length: 160, dtype: float64

# %%
Ytrain-Ypred_train
# Out:
# 79     1.315124
# 197    0.081630
# 38     0.053139
# 24     1.482764
# 122   -1.904996
#          ...
# 106    0.956197
# 14     0.569745
# 92     0.247040
# 179    0.258065
# 102   -2.686865
# Name: Sales, Length: 160, dtype: float64
